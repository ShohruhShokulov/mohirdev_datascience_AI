# %% [markdown]
# <a href="https://colab.research.google.com/github/ShohruhShokulov/mohirdev_datascience_AI/blob/main/pandas_day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # Pandas is a Python library used for working with data sets
import numpy as np

# %%
from pandas import Series
a = Series([1,2,3,4,5])

# %%
print(a)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
a.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
a.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
a[0]
# Out:
# 1

# %%
obj = Series([1,2,3,4,5], index = ['a','b','c','d','e'])
obj
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
obj["a"]
# Out:
# 1

# %%
obj[['a','b','c']]
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
obj[obj<4] # filtering
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
obj * 2
# Out:
# a     2
# b     4
# c     6
# d     8
# e    10
# dtype: int64

# %%
np.log(obj)
# Out:
# a    0.000000
# b    0.693147
# c    1.098612
# d    1.386294
# e    1.609438
# dtype: float64

# %%
calories = {'day1': 420,'day2':450,'day3':1200}
x = pd.Series(calories)
x
# Out:
# day1     420
# day2     450
# day3    1200
# dtype: int64

# %%
y = pd.Series(calories,index = ['day1','day4'])
y
# Out:
# day1    420.0
# day4      NaN
# dtype: float64

# %%
# Series methods
y.isnull() # if element in series equal to 0 which means that this element is NaN, it will return frue
# Out:
# day1    False
# day4     True
# dtype: bool

# %%
x.name = 'Calories'
x.index.name = 'days'

# %%
x
# Out:
# days
# day1     420
# day2     450
# day3    1200
# Name: Calories, dtype: int64

# %%
x.iloc[0] # by index
# Out:
# 420

# %%
x.loc['day1']
# Out:
# 420

# %%
x.mean()
# Out:
# 690.0

# %% [markdown]
# ## pandas data Frame

# %%
# DAtaFrame
data = {'calories': [450,460,709,367],
        'duration': [40,45,45,50]}

# %%
import pandas as pd
df = pd.DataFrame(data) # creating DataFraming from the given dictationary above
df
# Out:
#    calories  duration
# 0       450        40
# 1       460        45
# 2       709        45
# 3       367        50

# %%
# methods of DataFrame
df1 = pd.DataFrame(data,index = ['day1','day2','day3','day4'])
df1
# Out:
#       calories  duration
# day1       450        40
# day2       460        45
# day3       709        45
# day4       367        50

# %%
df1.loc['day1']
# Out:
# calories    450
# duration     40
# Name: day1, dtype: int64

# %%
# size of data frame using "shape" function
df.shape
# Out:
# (4, 2)

# %%
# to see first 5 elements of the data frame we can use "head" method
df.head(2) # to see first two elements of the data frame
# Out:
#    calories  duration
# 0       450        40
# 1       460        45

# %%
df2 = pd.DataFrame(data, columns = ['duration','calories']) # we can assign name of the column using this method
df2
# Out:
#    duration  calories
# 0        40       450
# 1        45       460
# 2        45       709
# 3        50       367

# %%
df2 = pd.DataFrame(data, columns = ['duration','calories', 'days']) # we can assign name of the column using this method
df2
# Out:
#    duration  calories days
# 0        40       450  NaN
# 1        45       460  NaN
# 2        45       709  NaN
# 3        50       367  NaN

# %%
a  =  df2['calories']
type(a)
# Out:
# pandas.core.series.Series

# %%
df2.days =  [1,2,3,4]

# %%
df2
# Out:
#    duration  calories  days
# 0        40       450     1
# 1        45       460     2
# 2        45       709     3
# 3        50       367     4

# %%
df2.days = pd.Series([1,2],index = [1,3])
df2
# Out:
#    duration  calories  days
# 0        40       450   NaN
# 1        45       460   1.0
# 2        45       709   NaN
# 3        50       367   2.0

# %%
df2['45+'] = df2.duration>=45 # using this method we can add one more column
df2
# Out:
#    duration  calories  days    45+
# 0        40       450   NaN  False
# 1        45       460   1.0   True
# 2        45       709   NaN   True
# 3        50       367   2.0   True

# %%
# delete column function
del df2['45+']

# %%
df2
# Out:
#    duration  calories  days
# 0        40       450   NaN
# 1        45       460   1.0
# 2        45       709   NaN
# 3        50       367   2.0

# %%
data = {'Uzbekistan': {2024: 12,2023:40,2022:34,2021:57},
        'Kazakistan': {2024: 29,2023:90,2022:14,2021:7}}
df = pd.DataFrame(data)
df
# Out:
#       Uzbekistan  Kazakistan
# 2024          12          29
# 2023          40          90
# 2022          34          14
# 2021          57           7

# %%
df.index.name = 'Year'
df
# Out:
#       Uzbekistan  Kazakistan
# Year
# 2024          12          29
# 2023          40          90
# 2022          34          14
# 2021          57           7

# %%
df3 = pd.DataFrame(data, index = [2021,2022])
df3
# Out:
#       Uzbekistan  Kazakistan
# 2021          57           7
# 2022          34          14

# %%
# Transpose method in panda same as numpy
df.T
# Out:
# Year        2024  2023  2022  2021
# Uzbekistan    12    40    34    57
# Kazakistan    29    90    14     7

# %%
df.values
# Out:
# array([[12, 29],
#        [40, 90],
#        [34, 14],
#        [57,  7]])
